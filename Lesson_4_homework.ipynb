# %%
#Exercise 4
my_string = " PATIENT_age_YEARS "
my_string_spaces_removed = my_string.strip()
print(my_string_spaces_removed)
my_string_lower_case = my_string_spaces_removed.lower()
print(my_string_lower_case)
my_string_no_underscore = my_string_lower_case.replace('_', ' ')
print(my_string_no_underscore)
result = my_string_no_underscore.title()
print(result)
# Out:
# PATIENT_age_YEARS
# patient_age_years
# patient age years
# Patient Age Years

# %%
Accuracy: 0.9234
Precision: 0.8891
Recall: 0.9456

# %%
data = {'Accuracy': 0.9234, 'Precision': 0.9456, 'Recall': 0.9456}
print(data)
# Out:
# {'Accuracy': 0.9234, 'Precision': 0.9456, 'Recall': 0.9456}

# %%
list_of_keys = list(data.keys())

# %%
print(f'{list_of_keys[0]:<20}{list_of_keys[1]:<20}{list_of_keys[2]:<20}')
print(f'{data[list_of_keys[0]]:<20.2f}{data[list_of_keys[1]]:<20.2f}{data[list_of_keys[2]]:<20.2f}')
# Out:
# Accuracy            Precision           Recall
# 0.92                0.95                0.95
